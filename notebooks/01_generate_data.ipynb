# %% [markdown]
# Generate synthetic tourism data.

# %%
from pathlib import Path
from src.data_generation.generate import generate_dataset

# %%
paths = generate_dataset(rows=200_000, output_dir=Path('data/raw'), seed=42)
paths

# %%
import pandas as pd
pd.read_csv('data/raw/visits.csv').head()
